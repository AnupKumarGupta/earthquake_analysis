# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv("earthquake_database.csv")
X_input = data_frame[['Latitude', 'Longitude']].as_matrix()
Y_input = data_frame['Magnitude']
X_input_list = data_frame['Latitude'].tolist()
Y_input_list = data_frame['Magnitude'].tolist()

# %%
plt.plot(Y_input_list, X_input_list,'ro')
plt.show()

# %%
X_input_list = data_frame['Longitude'].tolist()
plt.plot(Y_input_list, X_input_list,'ro')
plt.show()
